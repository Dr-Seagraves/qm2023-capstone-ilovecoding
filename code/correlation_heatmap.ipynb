# %%
# Create figure again for saving (in case the display was closed)
fig, ax = plt.subplots(figsize=(14, 10))

sns.heatmap(correlation_matrix, 
            annot=True, fmt='.3f', cmap='RdBu_r', center=0,
            vmin=-1, vmax=1, square=True, linewidths=0.5,
            cbar_kws={"shrink": 0.8, "label": "Correlation Coefficient"},
            ax=ax)

ax.set_title('Correlation Heatmap: REIT Returns and Financial Variables\n(2000-2024)', 
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Variables', fontsize=12, fontweight='bold')
ax.set_ylabel('Variables', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()

# Save figure
output_file = FIGURES_DIR / 'reit_correlation_heatmap.png'
plt.savefig(output_file, dpi=300, bbox_inches='tight')
print(f"✓ Heatmap saved to: {output_file}")

# Also save as PDF for publication quality
output_pdf = FIGURES_DIR / 'reit_correlation_heatmap.pdf'
plt.savefig(output_pdf, bbox_inches='tight')
print(f"✓ PDF version saved to: {output_pdf}")

plt.close()

print("\n" + "="*80)
print("ANALYSIS COMPLETE")
print("="*80)
print(f"Dataset: {len(df_clean):,} complete observations")
print(f"Variables analyzed: {len(correlation_matrix.columns)}")
print(f"Figures saved to: {FIGURES_DIR}")

# %% [markdown]
# ## 7. Save the Heatmap
#
# Export the correlation heatmap to the results/figures directory.

# %%
# Create figure and axis
fig, ax = plt.subplots(figsize=(14, 10))

# Create heatmap
sns.heatmap(correlation_matrix, 
            annot=True,  # Show correlation values
            fmt='.3f',   # Format to 3 decimal places
            cmap='RdBu_r',  # Red-Blue diverging colormap
            center=0,    # Center colormap at 0
            vmin=-1, vmax=1,  # Set range from -1 to 1
            square=True,  # Make cells square
            linewidths=0.5,  # Add gridlines
            cbar_kws={"shrink": 0.8, "label": "Correlation Coefficient"},
            ax=ax)

# Customize the plot
ax.set_title('Correlation Heatmap: REIT Returns and Financial Variables\n(2000-2024)', 
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Variables', fontsize=12, fontweight='bold')
ax.set_ylabel('Variables', fontsize=12, fontweight='bold')

# Rotate labels for better readability
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Show plot
plt.show()

print("\n✓ Heatmap generated successfully!")

# %% [markdown]
# ## 6. Create Correlation Heatmap
#
# Generate a comprehensive heatmap showing correlations between all financial variables including REIT returns.

# %%
# Calculate correlation matrix
correlation_matrix = df_clean.corr()

print("Correlation Matrix:")
display(correlation_matrix)

# Focus on correlations with returns (usdret)
if 'usdret' in correlation_matrix.columns:
    print("\nCorrelations with REIT Returns (usdret):")
    returns_corr = correlation_matrix['usdret'].sort_values(ascending=False)
    display(returns_corr)

# %% [markdown]
# ## 5. Calculate Correlation Matrix

# %%
# Select numeric columns relevant for correlation analysis
# Focus on returns, financial metrics, and market variables
numeric_cols = ['usdret', 'market_equity', 'assets', 'sales', 'net_income', 
                'book_equity', 'debt_at', 'cash_at', 'ocf_at', 'roe', 'btm', 'beta']

# Filter to columns that exist in the dataset
available_cols = [col for col in numeric_cols if col in df.columns]
print(f"Available numeric columns: {available_cols}")

# Create subset with relevant columns
df_analysis = df[available_cols].copy()

# Remove rows with missing values
print(f"\nRows before cleaning: {len(df_analysis):,}")
df_clean = df_analysis.dropna()
print(f"Rows after cleaning: {len(df_clean):,}")
print(f"Rows removed: {len(df_analysis) - len(df_clean):,}")

# Display cleaned data info
print(f"\nCleaned dataset shape: {df_clean.shape}")
display(df_clean.describe())

# %% [markdown]
# ## 4. Clean Data and Select Variables
#
# Remove rows with missing values and select relevant financial variables for correlation analysis.

# %%
# Display summary statistics for key variables
print("Data types:")
display(df.dtypes)

print("\nFirst few rows:")
display(df.head(10))

print("\nBasic statistics:")
display(df.describe())

# %% [markdown]
# ## 3. Examine Available Variables

# %%
# Load REIT data
input_file = RAW_DATA_DIR / "REIT_sample_2000_2024_All_Variables.csv"
df = pd.read_csv(input_file)

print(f"Data loaded: {df.shape[0]:,} rows × {df.shape[1]} columns")
print(f"\nColumn names:")
print(df.columns.tolist())

# %% [markdown]
# ## 2. Load the REIT Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import sys

# Add project root to path
project_root = Path.cwd().parent if 'code' in Path.cwd().parts else Path.cwd()
sys.path.append(str(project_root))

from config_paths import RAW_DATA_DIR, FIGURES_DIR

# Set visualization style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

print("Libraries imported successfully!")

# %% [markdown]
# ## 1. Import Required Libraries

# %% [markdown]
# # Correlation Heatmap: Interest Rates vs REIT Returns
#
# This notebook creates a correlation heatmap to analyze the relationship between interest rates and REIT returns.
